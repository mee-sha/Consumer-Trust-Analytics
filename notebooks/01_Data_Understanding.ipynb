# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/edtech_reviews.csv")

# %%
df.shape
# Out:
# (38000, 15)

# %%
df.columns
# Out:
# Index(['platform', 'category', 'source', 'review_id', 'rating', 'review',
#        'review_date', 'thumbs_up', 'app_version', 'reply_content',
#        'replied_at', 'review_length', 'review_year', 'review_month',
#        'rating_category'],
#       dtype='str')

# %%
df.head()
# Out:
#    platform category       source                             review_id  \
# 0  Coursera     MOOC  Google Play  d43c2954-87a9-4c88-9753-c35feb505ef0
# 1  Coursera     MOOC  Google Play  3d82399b-4d3d-46d2-9373-109a8b19e55d
# 2  Coursera     MOOC  Google Play  694b2fdc-0a9e-4d55-9eab-295de0affddf
# 3  Coursera     MOOC  Google Play  f779f734-a669-4da8-aeeb-0210bad34df4
# 4  Coursera     MOOC  Google Play  6007ea9a-4045-4276-b681-237211fb822d
#
#    rating                                             review  \
# 0       1  I was excited to enroll in this program. I sig...
# 1       2  Please do not block your app on alternate OSes...
# 2       5             This is a best app to learn any course
# 3       1  not able to submit my assignment and do not kn...
# 4       3  I like the Download option, but those Question...
#
#            review_date  thumbs_up app_version reply_content replied_at  \
# 0  2026-07-15 02:45:09          0       6.7.1           NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38000 entries, 0 to 37999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   platform         38000 non-null  str
#  1   category         38000 non-null  str
#  2   source           38000 non-null  str
#  3   review_id        38000 non-null  str
#  4   rating           38000 non-null  int64
#  5   review           37999 non-null  str
#  6   review_date      38000 non-null  str
#  7   thumbs_up        38000 non-null  int64
#  8   app_version      30928 non-null  str
#  9   reply_content    9036 non-null   str
#  10  replied_at       9036 non-null   str
#  11  review_length    37999 non-null  float64
#  12  review_year      38000 non-null  int64
#  13  review_month     38000 non-null  str
#  14  rating_category  38000 non-null  str
# dtypes: float64(1), int64(3), str(11)
# memory usage: 4.3 MB

# %%
df.describe()
# Out:
#              rating     thumbs_up  review_length   review_year
# count  38000.000000  38000.000000   37999.000000  38000.000000
# mean       3.869237      1.463395      82.987579   2024.973947
# std        1.611079     11.269056     109.902073      2.098600
# min        1.000000      0.000000       1.000000   2016.000000
# 25%        3.000000      0.000000      14.000000   2025.000000
# 50%        5.000000      0.000000      38.000000   2026.000000
# 75%        5.000000      1.000000     102.000000   2026.000000
# max        5.000000    573.000000    1151.000000   2026.000000

# %%
# Missing Values Analysis

df.isnull().sum()
# Out:
# platform               0
# category               0
# source                 0
# review_id              0
# rating                 0
# review                 1
# review_date            0
# thumbs_up              0
# app_version         7072
# reply_content      28964
# replied_at         28964
# review_length          1
# review_year            0
# review_month           0
# rating_category        0
# dtype: int64

# %%
df = df.dropna(subset=["review"])

# %%
df.isnull().sum()
# Out:
# platform               0
# category               0
# source                 0
# review_id              0
# rating                 0
# review                 0
# review_date            0
# thumbs_up              0
# app_version         7072
# reply_content      28963
# replied_at         28963
# review_length          0
# review_year            0
# review_month           0
# rating_category        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
